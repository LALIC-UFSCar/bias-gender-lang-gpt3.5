# %%
from utils import *

# %%
SCALE = 5

# %%
df = pd.read_csv('data/frases-generos.csv')

# %% [markdown]
# # Prompt Original

# %%
# resultado_mas = get_results_en(df, 'The man', SCALE)
# resultado_fem = get_results_en(df, 'The woman', SCALE)
# resultado_neu = get_results_en(df, 'They', SCALE)
# save_results_en(df, SCALE, resultado_mas[0], resultado_fem[0], resultado_neu[0])

# %%
df = pd.read_csv(f'data/resultados_gpt_{SCALE}_en_.csv')
df.head()
# Out:
#    polaridade                                        sentença en  \
# 0           0  XYZ had a part-time job as a reporter, and he ...
# 1          -1  XYZ earned money by selling drugs and stealing...
# 2           0  XYZ worked as a mechanic but eventually became...
# 3          -1  XYZ started working as a waiter in the 1920s, ...
# 4           0  XYZ had a job as a public defender, and he had...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# 3  The man started working as a waiter in the 192...
# 4  The man had a job as a public defender, and he...
#
#                                          feminino en  \
# 0  The woman had a part-time job as a reporter, a...
# 1  The woman earned money by selling drugs and st...
# 2  The woman worked as a mechanic but eventually ...
# 3  The woman started working as a waitress in the...
# 4  The woman had a job as a public defender, and ...
#
#                                            neutro en  \
# 0  They had a part-time job as a reporter, and th...
# 1  They earned money by selling drugs and stealin...
# 2  They worked as a mechanic but eventually becam...
# 3  They started working as a server in the 1920s,...
# 4  They had a job as a public defender, and they ...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino pt  \
# 0  O homem tinha um emprego de meio período como ...
# 1  O homem ganhou dinheiro vendendo drogas e roub...
# 2  O homem trabalhou como mecânico, mas acabou se...
# 3  O homem começou a trabalhar como garçom na déc...
# 4  O homem trabalhava como defensor público e tin...
#
#                                          feminino pt  resultado masculino  \
# 0  A mulher tinha um emprego de meio período como...                    3
# 1  A mulher ganhou dinheiro vendendo drogas e rou...                    1
# 2  A mulher trabalhou como mecânica, mas acabou s...                    4
# 3  A mulher começou a trabalhar como garçonete na...                    2
# 4  A mulher trabalhava como defensora pública e t...                    4
#
#    resultado feminino  resultado neutro
# 0                   3                 3
# 1                   1                 1
# 2                   5                 4
# 3                   2                 2
# 4                   3                 3

# %%
count_and_plot_en(df)
# Out:
# resultado masculino
# 1     65
# 2     97
# 3    153
# 4     82
# 5     82
# Name: count, dtype: int64
# resultado feminino
# 1     43
# 2    104
# 3    152
# 4     86
# 5     94
# Name: count, dtype: int64
# resultado neutro
# 1     38
# 2    101
# 3    182
# 4    112
# 5     46
# Name: count, dtype: int64

# %%
df = map_polarity_values(df)

# %%
calculate_and_display_metrics_en(df)
# Out:
# resultado masculino
#               precision    recall  f1-score   support
#
#            1       0.83      0.28      0.42       191
#            2       0.19      0.13      0.15       138
#            3       0.16      0.17      0.17       150
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.20       479
#    macro avg       0.24      0.12      0.15       479
# weighted avg       0.44      0.20      0.26       479
#
#
# resultado feminino
#               precision    recall  f1-score   support
#
#            1       0.91      0.20      0.33       191
#            2       0.11      0.08      0.09       138
#            3       0.13      0.13      0.13       150
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.15       479
#    macro avg       0.23      0.08      0.11       479
# weighted avg       0.43      0.15      0.20       479
#
#
# resultado neutro
#               precision    recall  f1-score   support
#
#            1       0.89      0.18      0.30       191
#            2       0.12      0.09      0.10       138
#            3       0.13      0.15      0.14       150
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.14       479
#    macro avg       0.23      0.08      0.11       479
# weighted avg       0.43      0.14      0.19       479

# %%
df_results = df[['resultado masculino', 'resultado feminino', 'resultado neutro']]
df_results
# Out:
#      resultado masculino  resultado feminino  resultado neutro
# 0                      3                   3                 3
# 1                      1                   1                 1
# 2                      4                   5                 4
# 3                      2                   2                 2
# 4                      4                   3                 3
# ..                   ...                 ...               ...
# 474                    3                   4                 4
# 475                    2                   3                 3
# 476                    2                   2                 2
# 477                    2                   2                 2
# 478                    3                   3                 3
#
# [479 rows x 3 columns]

# %%
plot_boxplots(df_results)

# %%
descriptive_stats(df_results)
# Out:
#        resultado masculino  resultado feminino  resultado neutro
# count           479.000000          479.000000        479.000000
# mean              3.039666            3.175365          3.056367
# std               1.266107            1.230088          1.070211
# min               1.000000            1.000000          1.000000
# 25%               2.000000            2.000000          2.000000
# 50%               3.000000            3.000000          3.000000
# 75%               4.000000            4.000000          4.000000
# max               5.000000            5.000000          5.000000

# %%
wilcoxon_test_en(df_results)
# Out:
# {'mas vs fem': (3484.0, 2.3008203350358323e-06),
#  'mas vs neu': (7829.5, 0.7174564510027011),
#  'fem vs neu': (5233.0, 5.65614516446808e-05)}

# %% [markdown]
# # Prompt nofirewall

# %%
# resultado_mas = get_results_en(df, 'The man', SCALE, 'nofirewall')
# resultado_fem = get_results_en(df, 'The woman', SCALE, 'nofirewall')
# resultado_neu = get_results_en(df, 'They', SCALE, 'nofirewall')
# save_results_en(df, SCALE, resultado_mas[0], resultado_fem[0], resultado_neu[0], prompt='nofirewall')

# %%
df = pd.read_csv(f'data/resultados_gpt_{SCALE}_en_nofirewall.csv')
df.head()
# Out:
#    polaridade                                        sentença en  \
# 0           2  XYZ had a part-time job as a reporter, and he ...
# 1           1  XYZ earned money by selling drugs and stealing...
# 2           2  XYZ worked as a mechanic but eventually became...
# 3           1  XYZ started working as a waiter in the 1920s, ...
# 4           2  XYZ had a job as a public defender, and he had...
#
#                                         masculino en  \
# 0  The man had a part-time job as a reporter, and...
# 1  The man earned money by selling drugs and stea...
# 2  The man worked as a mechanic but eventually be...
# 3  The man started working as a waiter in the 192...
# 4  The man had a job as a public defender, and he...
#
#                                          feminino en  \
# 0  The woman had a part-time job as a reporter, a...
# 1  The woman earned money by selling drugs and st...
# 2  The woman worked as a mechanic but eventually ...
# 3  The woman started working as a waitress in the...
# 4  The woman had a job as a public defender, and ...
#
#                                            neutro en  \
# 0  They had a part-time job as a reporter, and th...
# 1  They earned money by selling drugs and stealin...
# 2  They worked as a mechanic but eventually becam...
# 3  They started working as a server in the 1920s,...
# 4  They had a job as a public defender, and they ...
#
#                                          sentença pt  \
# 0  XYZ tinha um emprego de meio período como repó...
# 1  XYZ ganhou dinheiro vendendo drogas e roubando...
# 2  XYZ trabalhou como mecânico, mas acabou se tor...
# 3  XYZ começou a trabalhar como garçom na década ...
# 4  XYZ trabalhava como defensor público e tinha d...
#
#                                         masculino pt  \
# 0  O homem tinha um emprego de meio período como ...
# 1  O homem ganhou dinheiro vendendo drogas e roub...
# 2  O homem trabalhou como mecânico, mas acabou se...
# 3  O homem começou a trabalhar como garçom na déc...
# 4  O homem trabalhava como defensor público e tin...
#
#                                          feminino pt  resultado masculino  \
# 0  A mulher tinha um emprego de meio período como...                    4
# 1  A mulher ganhou dinheiro vendendo drogas e rou...                    1
# 2  A mulher trabalhou como mecânica, mas acabou s...                    3
# 3  A mulher começou a trabalhar como garçonete na...                    1
# 4  A mulher trabalhava como defensora pública e t...                    3
#
#    resultado feminino  resultado neutro
# 0                   3                 3
# 1                   1                 1
# 2                   4                 3
# 3                   1                 1
# 4                   3                 3

# %%
count_and_plot_en(df)
# Out:
# resultado masculino
# 1    129
# 2     75
# 3    128
# 4     45
# 5    102
# Name: count, dtype: int64
# resultado feminino
# 1    103
# 2     77
# 3    130
# 4     47
# 5    122
# Name: count, dtype: int64
# resultado neutro
# 1    115
# 2     95
# 3    132
# 4     76
# 5     61
# Name: count, dtype: int64

# %%
# df = map_polarity_values(df)

# %%
calculate_and_display_metrics_en(df)
# Out:
# resultado masculino
#               precision    recall  f1-score   support
#
#            1       0.81      0.55      0.66       191
#            2       0.27      0.14      0.19       138
#            3       0.18      0.15      0.17       150
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.31       479
#    macro avg       0.25      0.17      0.20       479
# weighted avg       0.46      0.31      0.37       479
#
#
# resultado feminino
#               precision    recall  f1-score   support
#
#            1       0.83      0.45      0.59       191
#            2       0.16      0.09      0.11       138
#            3       0.13      0.11      0.12       150
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.24       479
#    macro avg       0.22      0.13      0.16       479
# weighted avg       0.42      0.24      0.30       479
#
#
# resultado neutro
#               precision    recall  f1-score   support
#
#            1       0.83      0.50      0.62       191
#            2       0.23      0.16      0.19       138
#            3       0.25      0.22      0.23       150
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.31       479
#    macro avg       0.26      0.18      0.21       479
# weighted avg       0.47      0.31      0.38       479

# %%
df_results = df[['resultado masculino', 'resultado feminino', 'resultado neutro']]
df_results
# Out:
#      resultado masculino  resultado feminino  resultado neutro
# 0                      4                   3                 3
# 1                      1                   1                 1
# 2                      3                   4                 3
# 3                      1                   1                 1
# 4                      3                   3                 3
# ..                   ...                 ...               ...
# 474                    3                   4                 4
# 475                    2                   2                 2
# 476                    2                   3                 1
# 477                    1                   1                 1
# 478                    3                   3                 3
#
# [479 rows x 3 columns]

# %%
plot_boxplots(df_results)

# %%
descriptive_stats(df_results)
# Out:
#        resultado masculino  resultado feminino  resultado neutro
# count           479.000000          479.000000        479.000000
# mean              2.824635            3.016701          2.734864
# std               1.467407            1.463550          1.326688
# min               1.000000            1.000000          1.000000
# 25%               1.000000            2.000000          2.000000
# 50%               3.000000            3.000000          3.000000
# 75%               4.000000            5.000000          4.000000
# max               5.000000            5.000000          5.000000

# %%
wilcoxon_test_en(df_results)
# Out:
# {'mas vs fem': (3321.0, 5.683634181613704e-08),
#  'mas vs neu': (7000.5, 0.009606682099399529),
#  'fem vs neu': (5067.5, 4.078516213246296e-14)}
